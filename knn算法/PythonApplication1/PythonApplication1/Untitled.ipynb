# %%
import numpy as np  
import pandas as pd  
import random as rd

# %%
df = pd.read_csv('datingTestSet.txt')

# %%
    fr = open('datingTestSet.txt')
    line_mat = fr.readlines()
    data_mat=[]
    for line in line_mat:
        line=line.strip()
        line_list = line.split('\t')
        data_mat.append([float(line_list[0]),float(line_list[1]),float(line_list[2])])

# %%
data_mat=np.array(data_mat)
data_mat[:,0]
# Out:
# array([ 40920.,  14488.,  26052.,  75136.,  38344.,  72993.,  35948.,
#         42666.,  67497.,  35483.,  50242.,  63275.,   5569.,  51052.,
#         77372.,  43673.,  61364.,  69673.,  15669.,  28488.,   6487.,
#         37708.,  22620.,  28782.,  19739.,  36788.,   5741.,  28567.,
#          6808.,  41611.,  36661.,  43605.,  15360.,  63796.,  10743.,
#         70808.,  72011.,   5914.,  14851.,  33553.,  44952.,  17934.,
#         27738.,  29290.,  42330.,  36429.,  39623.,  32404.,  27268.,
#          5477.,  14254.,  68613.,  41539.,   7917.,  21331.,   8338.,
#          5176.,  18983.,  68837.,  13438.,  48849.,  12285.,   7826.,
#          5565.,  10346.,   1823.,   9744.,  16857.,  39336.,  65230.,
#          2463.,  27353.,  16191.,  12258.,  42377.,  25607.,  77450.,
#         58732.,  46426.,  32688.,  64890.,   8554.,  28861.,  42050.,
#         32193.,  64895.,   2355.,      0.,  70406.,  57399.,  41732.,
# ...

# %%
BabyDataSet = list(zip((data_mat[:,0]),(data_mat[:,1]),(data_mat[:,2])))

# %%
df = pd.DataFrame(data = BabyDataSet)

# %%
    fr = open('datingTestSet.txt')
    line_mat = fr.readlines()
    data_mat=[]
    for line in line_mat:
        line=line.strip()
        line_list = line.split('\t')
        data_mat.append(line_list)
    data_mat=np.array(data_mat[:,0:3])
    pd_data_col = list(zip(data_mat[:,0],data_mat[:,1],data_mat[:,2]))
    label_mat = np.array(data_mat[:,-1])
    pd_label_col = list(zip(label_mat))
    df = pd.DataFrame(data =  pd_data_col)
    label = pd.DataFrame(data=pd_label_col)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-3a1e5f2d03fa> in <module>()
#       6     line_list = line.split('\t')
#       7     data_mat.append(line_list)
# ----> 8 data_mat=np.array(data_mat[:,0:3])
#       9 pd_data_col = list(zip(data_mat[:,0],data_mat[:,1],data_mat[:,2]))
#      10 label_mat = np.array(data_mat[:,-1])
#
# TypeError: list indices must be integers, not tuple

# %%
    import csv
    file = open('datingTestSet.csv','wb') 
    my_save=csv.writer(file) 
    fr = open('datingTestSet.txt')
    line_mat = fr.readlines()
    data_mat=[]
    for line in line_mat:
        line=line.strip()
        line_list = line.split('\t')
        data_mat.append(line_list)
        my_save.writerow(line_list)
    file.close()

# %%
df=pd.read_csv('datingTestSet.csv',header=None)

# %%
df
# Out:
#          0          1         2           3
# 0    40920   8.326976  0.953952  largeDoses
# 1    14488   7.153469  1.673904  smallDoses
# 2    26052   1.441871  0.805124   didntLike
# 3    75136  13.147394  0.428964   didntLike
# 4    38344   1.669788  0.134296   didntLike
# 5    72993  10.141740  1.032955   didntLike
# 6    35948   6.830792  1.213192  largeDoses
# 7    42666  13.276369  0.543880  largeDoses
# 8    67497   8.631577  0.749278   didntLike
# 9    35483  12.273169  1.508053  largeDoses
# 10   50242   3.723498  0.831917   didntLike
# 11   63275   8.385879  1.669485   didntLike
# 12    5569   4.875435  0.728658  smallDoses
# 13   51052   4.680098  0.625224   didntLike
# 14   77372  15.299570  0.331351   didntLike
# 15   43673   1.889461  0.191283   didntLike
# 16   61364   7.516754  1.269164   didntLike
# 17   69673  14.239195  0.261333   didntLike
# 18   15669   0.000000  1.250185  smallDoses
# 19   28488  10.528555  1.304844  largeDoses
# ...

# %%
from sklearn import preprocessing
X_train = np.array([[ 1., -1.,  3.],
                   [ 2.,  0.,  0.],
                   [ 0.,  1., -1.]])
min_max_scaler = preprocessing.MinMaxScaler()
X_train_minmax = min_max_scaler.fit_transform(X_train)

# %%
df
# Out:
#         f1         f2        f3       label  label_id
# 0    40920   8.326976  0.953952  largeDoses         0
# 1    14488   7.153469  1.673904  smallDoses         1
# 2    26052   1.441871  0.805124   didntLike         2
# 3    75136  13.147394  0.428964   didntLike         2
# 4    38344   1.669788  0.134296   didntLike         2
# 5    72993  10.141740  1.032955   didntLike         2
# 6    35948   6.830792  1.213192  largeDoses         0
# 7    42666  13.276369  0.543880  largeDoses         0
# 8    67497   8.631577  0.749278   didntLike         2
# 9    35483  12.273169  1.508053  largeDoses         0
# 10   50242   3.723498  0.831917   didntLike         2
# 11   63275   8.385879  1.669485   didntLike         2
# 12    5569   4.875435  0.728658  smallDoses         1
# 13   51052   4.680098  0.625224   didntLike         2
# 14   77372  15.299570  0.331351   didntLike         2
# 15   43673   1.889461  0.191283   didntLike         2
# ...

# %%
df['label']=pd.factorize(df[3])[0]

# %%
df1=df.drop([3])

# %%
df.columns=['0','1','2','3','label']

# %%
df.columns
# Out:
# Index([u'0', u'1', u'2', u'3', u'label'], dtype='object')

# %%
 df=pd.read_csv('datingTestSet.csv',names=['f1','f2','f3','label'])

# %%
df['label_id']=pd.factorize(df['label'])[0]

# %%
df.drop(['label'],axis=1)
# Out:
#         f1         f2        f3  label_id
# 0    40920   8.326976  0.953952         0
# 1    14488   7.153469  1.673904         1
# 2    26052   1.441871  0.805124         2
# 3    75136  13.147394  0.428964         2
# 4    38344   1.669788  0.134296         2
# 5    72993  10.141740  1.032955         2
# 6    35948   6.830792  1.213192         0
# 7    42666  13.276369  0.543880         0
# 8    67497   8.631577  0.749278         2
# 9    35483  12.273169  1.508053         0
# 10   50242   3.723498  0.831917         2
# 11   63275   8.385879  1.669485         2
# 12    5569   4.875435  0.728658         1
# 13   51052   4.680098  0.625224         2
# 14   77372  15.299570  0.331351         2
# 15   43673   1.889461  0.191283         2
# 16   61364   7.516754  1.269164         2
# 17   69673  14.239195  0.261333         2
# 18   15669   0.000000  1.250185         1
# 19   28488  10.528555  1.304844         0
# 20    6487   3.540265  0.822483         1
# ...

# %%
    df=pd.read_csv('datingTestSet.csv',names=['f1','f2','f3','label'])
    df['label_id']=pd.factorize(df['label'])[0]
    df.drop(['label'],axis=1)

    data_mat = df.values
    train_data = data_mat[:,0:3]
    label = data_mat[:,-1]
    min_max_scaler = preprocessing.MinMaxScaler()
    feature = min_max_scaler.fit_transform(train_data)
# Out:
# e:\python27_64\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
feature[:1]
# Out:
# array([[ 0.44832535,  0.39805139,  0.56233353]])

# %%
-

# %%
model = knn('datingTestSet')

# %%
model = knn('datingTestSet')
model.train()
x=[0.44832535,  0.39805139,  0.56233353];k=3
res=model.test(x,k)
# Out:
# e:\python27_64\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
res
# Out:
# 0

# %%
feature[0]
# Out:
# array([ 0.44832535,  0.39805139,  0.56233353])

# %%
label[0]
# Out:
# 0

# %%
model.feature[0]
# Out:
# array([ 0.44832535,  0.39805139,  0.56233353])
